# %% [markdown]
# <a href="https://colab.research.google.com/github/AsmaQari/KAUSTTask/blob/main/2nd_day_Dec1%2C_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
age = 20

age
# Out:
# 20

# %%
age += 20  # لازم يكون += | بالترتيب هذا بالزبط

age
# Out:
# 100

# %%
first_name = "Alice"
last_name = "Smith"
full_name = first_name + " " + last_name

full_name
# Out:
# 'Alice Smith'

# %%
first_name = str(input("Enter your name:"))
last_name = str(input("Enter your name:"))

full_name = first_name + " " + last_name

full_name
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3887984662.py in <cell line: 0>()
# ----> 1 first_name = str(input("Enter your name:"))
#       2 last_name = str(input("Enter your name:"))
#       3
#       4 full_name = first_name + " " + last_name
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
PI = 3.14

type (PI)

x = 3
y = 5

type (x)

# %%
W = int(input("Enter width:"))
H = int(input("Enter width:"))

area = H * W

area
# Out:
# Enter width:9
# Enter width:8
# 72

# %%
your_age = int(input("Enter age:"))

your_age += 10

your_age
# Out:
# Enter age:44
# 54

# %%
#excersise

H - 40
W = 60
L = 10

Area = H * W * L

# %%
import math


radius = 5
radius_squared = radius ** 2


AreaOfCicrle = math.pi * radius_squared
AreaOfCicrle
# Out:
# 78.53981633974483

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
work_hours = int(input("Enter your total work hours"))
rate_by_hour = int(input("Enter your rate by hour"))

gross_pay = work_hours * rate_by_hour
gross_pay
# Out:
# Enter your total work hours50
# Enter your rate by hour100
# 5000

# %%
random_var1 = int(input("enter a variable"))
random_var2 = int(input("enter a variable"))

sum = random_var1 + random_var2
diff = random_var1 - random_var2
product = random_var1 * random_var2
quotient = random_var1 / random_var2

sum, diff, product, quotient
# Out:
# enter a variable30
# enter a variable22
# (52, 8, 660, 1.3636363636363635)

# %%
Temp_in_Celusisus = int(input("enter temp in Celsius"))
Temp_in_Feh = (Temp_in_Celusisus * 1.8)+ 32

print("Temp_in_Feh:  (Temp_in_Celusisus) \u00B0")
# Out:
# enter temp in Celsius77
# Temp_in_Feh:  (Temp_in_Celusisus) °

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
phone = str(input("enter phone num"))
msg = str(input("enter the msg"))
print(len(phone))
print(len(msg))
# Out:
# enter phone num7878
# enter the msghghghjlhgfdyuikb
# 4
# 16
